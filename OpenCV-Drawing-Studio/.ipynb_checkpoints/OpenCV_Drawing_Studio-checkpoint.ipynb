# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
blank_space = np.zeros((800,600,3), np.uint8)
cv2.namedWindow(winname="Canvas")
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(blank_space)

# %%
def mouse_events(event, x,y,params):
    print(x,y)
